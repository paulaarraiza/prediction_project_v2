# %%
import pandas as pd
import os

# %%
project_dir = "/home/jupyter-tfg2425paula"
os.chdir(project_dir)
data_dir = os.path.join(project_dir, "raw_data")
options_dir = os.path.join(data_dir, "options_and_combinations")
pca_dir = os.path.join(data_dir, "pca")

# %%
import sklearn.preprocessing

def normalize_data(df):
    min_max_scaler = sklearn.preprocessing.MinMaxScaler()
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
    
    
    for column in numeric_columns:  # Use 'df' instead of 'normalized_df' to iterate over its columns
        df[column] = min_max_scaler.fit_transform(df[column].values.reshape(-1, 1))  # Correct access to columns
    return df

# %%
from openpyxl import load_workbook

stocks = 'AAPL_MSFT_AMZN_NVDA_SPX'
filename = f'{stocks}_options.xlsx'
workbook = load_workbook(os.path.join(options_dir, filename))
sheet = workbook.active
data = []
for row in sheet.iter_rows(values_only=True):  # Iterate through rows, extract values
    data.append(row)

# Convert to pandas DataFrame
df = pd.DataFrame(data[1:], columns=data[0])
df.head()
# Out:
#         Date  AAPL_Close  AAPL_CALL_OM  AAPL_CALL_O1  AAPL_CALL_OY  \
# 0 2009-06-18      135.88          6.80        0.4063        0.4254
# 1 2009-06-19      139.48          5.40        0.3606        0.4244
# 2 2009-06-22      137.37          6.90        0.3852        0.4156
# 3 2009-06-23      134.01          4.52        0.3653        0.4180
# 4 2009-06-24      136.22          5.45        0.3513        0.4088
#
#    AAPL_CALL_OI  AAPL_CALL_VM  AAPL_PUT_OM  AAPL_PUT_O1  AAPL_PUT_OY  ...  \
# 0        920448       31936.0         5.70       0.3943       0.4314  ...
# 1        687080       40040.0         5.96       0.3654       0.4145  ...
# 2        708547       25673.0         4.45       0.3845       0.4333  ...
# 3        725825       24184.0         5.60       0.3747       0.4259  ...
# 4        732078       16474.0         4.10       0.3464       0.4138  ...
#
#    SPX_CALL_OM  SPX_CALL_O1  SPX_CALL_OY  SPX_CALL_OI  SPX_CALL_VM  \
# 0         24.3       0.2568       0.2698      3816626     360148.0
# 1         23.0       0.2335       0.2635      3889631     211146.0
# 2         24.4       0.2880       0.2804      3806131     195176.0
# 3         24.0       0.2734       0.2752      3755289     117641.0
# 4         24.0       0.2707       0.2763      4028277     225367.0
#
#    SPX_PUT_OM  SPX_PUT_O1  SPX_PUT_OY SPX_PUT_OI  SPX_PUT_VM
# 0       28.16      0.2656      0.2939    5607238    468262.0
# 1       25.00      0.2524      0.2950    5775618    296620.0
# 2       26.90      0.2799      0.3056    5685968    312092.0
# 3       25.00      0.2757      0.3059    5287312    312995.0
# 4       22.60      0.2595      0.2936    6065984    255662.0
#
# [5 rows x 56 columns]

# %%
filename = f'rotated_{stocks}_options.csv'
df = pd.read_csv(os.path.join(pca_dir, filename))
df.head()
# Out:
#    Rotated_PC1  Target
# 0         0.77     1.0
# 1         0.77     0.0
# 2         0.65     0.0
# 3         0.66     1.0
# 4         0.52     1.0

# %%
security = 'AAPL'

df[f'RETURN_{security}'] = (df[f'{security}_Close'] - df[f'{security}_Close'].shift(1)) / df[f'{security}_Close'].shift(1)
df[f'TARGET_{security}'] = (df[f'{security}_Close'].shift(-1) - df[f'{security}_Close'] > 0).astype(float)

df = df.drop(columns = ['Date'])
    
df = df.fillna(0)
df = df.rename(columns={f'TARGET_{security}': 'Target'})

normalized_df = normalize_data(df)

normalized_df.head()
# Out:
#    AAPL_Close  AAPL_CALL_OM  AAPL_CALL_O1  AAPL_CALL_OY  AAPL_CALL_OI  \
# 0    0.074532      0.166161      0.083655      0.145124      0.109092
# 1    0.080416      0.123711      0.070093      0.144516      0.081433
# 2    0.076967      0.169193      0.077393      0.139166      0.083977
# 3    0.071475      0.097029      0.071488      0.140625      0.086025
# 4    0.075087      0.125227      0.067333      0.135032      0.086766
#
#    AAPL_CALL_VM  AAPL_PUT_OM  AAPL_PUT_O1  AAPL_PUT_OY  AAPL_PUT_OI  ...  \
# 0      0.007441     0.136778     0.122097     0.052680     0.130542  ...
# 1      0.009329     0.144681     0.109138     0.048656     0.094416  ...
# 2      0.005982     0.098784     0.117702     0.053133     0.098452  ...
# 3      0.005635     0.133739     0.113308     0.051371     0.106272  ...
# 4      0.003838     0.088146     0.100619     0.048489     0.107550  ...
#
#    SPX_CALL_OY  SPX_CALL_OI  SPX_CALL_VM  SPX_PUT_OM  SPX_PUT_O1  SPX_PUT_OY  \
# 0     0.448234     0.495566     0.381835    0.095962    0.282048    0.312108
# 1     0.429218     0.505046     0.223861    0.085193    0.263833    0.314138
# 2     0.480229     0.494204     0.206929    0.091668    0.301780    0.333702
# 3     0.464534     0.487602     0.124725    0.085193    0.295985    0.334256
# 4     0.467854     0.523048     0.238938    0.077015    0.273630    0.311554
#
#    SPX_PUT_OI SPX_PUT_VM  RETURN_AAPL  Target
# 0    0.471325   0.202485     0.877078     1.0
# 1    0.485479   0.128264     0.904260     0.0
# 2    0.477943   0.134954     0.861557     0.0
# 3    0.444433   0.135345     0.851982     1.0
# 4    0.509886   0.110553     0.893998     1.0
#
# [5 rows x 57 columns]

# %%
def split_dataframe(df, target_column, window_size):
    """
    Splits the DataFrame into sequential portions of size `window_size`.

    Parameters:
    df (pd.DataFrame): The input DataFrame to be split.
    target_column (str): Name of the target column that indicates future changes.
    window_size (int): The size of each sequential portion.

    Returns:
    list: A list of DataFrames, each of size `window_size`.
    list: Corresponding targets for each sequential portion.
    """
    sequential_data = []
    targets = []

    for i in range(len(df) - window_size + 1):
        window = df.iloc[i:i + window_size].copy()  # Selects a window of size `window_size`
        target = df.iloc[i + window_size - 1][target_column]  # Target is the last value in the window
        sequential_data.append(window)
        targets.append(target)

    return sequential_data, targets

# %%
import pandas as pd

window_size = 200
sequential_data, targets = split_dataframe(normalized_df, target_column='Target', window_size=window_size)

print(f"Number of sequential portions: {len(sequential_data)}")
print("Example of one sequential portion:")
print(sequential_data[0])  # Show the first sequential portion
print("Corresponding target:", targets[0])
# Out:
# Number of sequential portions: 3829
# Example of one sequential portion:
#      AAPL_Close  AAPL_CALL_OM  AAPL_CALL_O1  AAPL_CALL_OY  AAPL_CALL_OI  \
# 0      0.074532      0.166161      0.083655      0.145124      0.109092
# 1      0.080416      0.123711      0.070093      0.144516      0.081433
# 2      0.076967      0.169193      0.077393      0.139166      0.083977
# 3      0.071475      0.097029      0.071488      0.140625      0.086025
# 4      0.075087      0.125227      0.067333      0.135032      0.086766
# ..          ...           ...           ...           ...           ...
# 195    0.219623      0.241662      0.040180      0.086150      0.071253
# 196    0.215701      0.196483      0.041575      0.086393      0.055799
# 197    0.219787      0.231352      0.042020      0.096790      0.058315
# 198    0.225687      0.123711      0.041842      0.087853      0.059276
# 199    0.227338      0.138872      0.043623      0.091196      0.060848
#
#      AAPL_CALL_VM  AAPL_PUT_OM  AAPL_PUT_O1  AAPL_PUT_OY  AAPL_PUT_OI  ...  \
# 0        0.007441     0.136778     0.122097     0.052680     0.130542  ...
# 1        0.009329     0.144681     0.109138     0.048656     0.094416  ...
# 2        0.005982     0.098784     0.117702     0.053133     0.098452  ...
# 3        0.005635     0.133739     0.113308     0.051371     0.106272  ...
# 4        0.003838     0.088146     0.100619     0.048489     0.107550  ...
# ..            ...          ...          ...          ...          ...  ...
# 195      0.005065     0.101824     0.060398     0.031127     0.095963  ...
# 196      0.006475     0.135258     0.065958     0.031770     0.058216  ...
# 197      0.006468     0.088146     0.062550     0.031413     0.060879  ...
# 198      0.007633     0.171733     0.061654     0.030127     0.063030  ...
# 199      0.007269     0.158055     0.065555     0.030818     0.064865  ...
#
#      SPX_CALL_OY  SPX_CALL_OI  SPX_CALL_VM  SPX_PUT_OM  SPX_PUT_O1  \
# 0       0.448234     0.495566     0.381835    0.095962    0.282048
# 1       0.429218     0.505046     0.223861    0.085193    0.263833
# 2       0.480229     0.494204     0.206929    0.091668    0.301780
# 3       0.464534     0.487602     0.124725    0.085193    0.295985
# 4       0.467854     0.523048     0.238938    0.077015    0.273630
# ..           ...          ...          ...         ...         ...
# 195     0.196800     0.540669     0.531519    0.064406    0.115772
# 196     0.208572     0.553912     0.226289    0.063145    0.116324
# 197     0.202837     0.562686     0.182299    0.057250    0.112322
# 198     0.194989     0.576898     0.289840    0.058272    0.113012
# 199     0.212194     0.588170     0.190662    0.061510    0.121982
#
#      SPX_PUT_OY  SPX_PUT_OI SPX_PUT_VM  RETURN_AAPL  Target
# 0      0.312108    0.471325   0.202485     0.877078     1.0
# 1      0.314138    0.485479   0.128264     0.904260     0.0
# 2      0.333702    0.477943   0.134954     0.861557     0.0
# 3      0.334256    0.444433   0.135345     0.851982     1.0
# 4      0.311554    0.509886   0.110553     0.893998     1.0
# ..          ...         ...        ...          ...     ...
# 195    0.138058    0.578345   0.270231     0.879504     0.0
# 196    0.143965    0.600430   0.305867     0.866117     1.0
# 197    0.141565    0.616148   0.195120     0.888619     1.0
# 198    0.142303    0.633132   0.140568     0.893557     1.0
# 199    0.141750    0.647345   0.169971     0.881615     0.0
#
# [200 rows x 57 columns]
# Corresponding target: 0.0

# %%
import pandas as pd

def create_sequential_dataframe(sequential_data, targets):
    """
    Creates a reshaped DataFrame where each row contains sequential data for each feature
    and a corresponding target value.

    Parameters:
    sequential_data (list): List of DataFrames representing sequential data portions.
    targets (list): List of target values corresponding to each sequence.

    Returns:
    pd.DataFrame: Reshaped DataFrame with each row containing sequential data for each feature
                  and the corresponding target value.
    """
    reshaped_rows = []

    for i, window_df in enumerate(sequential_data):
        row_data = {}
        # Iterate over columns (features) in the window
        for col in window_df.columns:
            # Create a new column for each feature across the window size
            row_data[col] = pd.Series(window_df[col].values)

        # Add the corresponding target for the sequence
        row_data['Target'] = targets[i]

        reshaped_rows.append(row_data)

    # Convert to DataFrame
    reshaped_df = pd.DataFrame(reshaped_rows)
    return reshaped_df

# %%
sequential_data, targets = split_dataframe(normalized_df, target_column='Target', window_size=window_size)
reshaped_df = create_sequential_dataframe(sequential_data, targets)

reshaped_df
# Out:
#                                              AAPL_Close  \
# 0     0      0.074532
# 1      0.080416
# 2      0.07696...
# 1     0      0.080416
# 1      0.076967
# 2      0.07147...
# 2     0      0.076967
# 1      0.071475
# 2      0.07508...
# 3     0      0.071475
# 1      0.075087
# 2      0.08103...
# 4     0      0.075087
# 1      0.081037
# 2      0.08525...
# ...                                                 ...
# 3824  0      0.153427
# 1      0.152953
# 2      0.15042...
# 3825  0      0.152953
# 1      0.150420
# 2      0.15042...
# 3826  0      0.150420
# 1      0.150420
# 2      0.14919...
# 3827  0      0.150420
# 1      0.149194
# 2      0.15043...
# 3828  0      0.149194
# 1      0.150436
# 2      0.15378...
#
#                                            AAPL_CALL_OM  \
# 0     0      0.166161
# 1      0.123711
# 2      0.16919...
# 1     0      0.123711
# 1      0.169193
# 2      0.09702...
# 2     0      0.169193
# 1      0.097029
# 2      0.12522...
# 3     0      0.097029
# 1      0.125227
# 2      0.09642...
# 4     0      0.125227
# 1      0.096422
# 2      0.12219...
# ...                                                 ...
# 3824  0      0.112189
# 1      0.108551
# 2      0.16919...
# 3825  0      0.108551
# 1      0.169193
# 2      0.16919...
# 3826  0      0.169193
# 1      0.169193
# 2      0.07580...
# 3827  0      0.169193
# 1      0.075804
# 2      0.08277...
# 3828  0      0.075804
# 1      0.082777
# 2      0.09551...
#
#                                            AAPL_CALL_O1  \
# 0     0      0.083655
# 1      0.070093
# 2      0.07739...
# 1     0      0.070093
# 1      0.077393
# 2      0.07148...
# 2     0      0.077393
# 1      0.071488
# 2      0.06733...
# 3     0      0.071488
# 1      0.067333
# 2      0.06314...
# 4     0      0.067333
# 1      0.063149
# 2      0.05130...
# ...                                                 ...
# 3824  0      0.019467
# 1      0.023325
# 2      0.02412...
# 3825  0      0.023325
# 1      0.024126
# 2      0.02412...
# 3826  0      0.024126
# 1      0.024126
# 2      0.02498...
# 3827  0      0.024126
# 1      0.024987
# 2      0.02418...
# 3828  0      0.024987
# 1      0.024185
# 2      0.01943...
#
#                                            AAPL_CALL_OY  \
# 0     0      0.145124
# 1      0.144516
# 2      0.13916...
# 1     0      0.144516
# 1      0.139166
# 2      0.14062...
# 2     0      0.139166
# 1      0.140625
# 2      0.13503...
# 3     0      0.140625
# 1      0.135032
# 2      0.12372...
# 4     0      0.135032
# 1      0.123723
# 2      0.11861...
# ...                                                 ...
# 3824  0      0.026629
# 1      0.028818
# 2      0.02906...
# 3825  0      0.028818
# 1      0.029061
# 2      0.02906...
# 3826  0      0.029061
# 1      0.029061
# 2      0.03039...
# 3827  0      0.029061
# 1      0.030399
# 2      0.02906...
# 3828  0      0.030399
# 1      0.029061
# 2      0.02620...
#
#                                            AAPL_CALL_OI  \
# 0     0      0.109092
# 1      0.081433
# 2      0.08397...
# 1     0      0.081433
# 1      0.083977
# 2      0.08602...
# 2     0      0.083977
# 1      0.086025
# 2      0.08676...
# 3     0      0.086025
# 1      0.086766
# 2      0.08688...
# 4     0      0.086766
# 1      0.086887
# 2      0.08772...
# ...                                                 ...
# 3824  0      0.263325
# 1      0.266434
# 2      0.02276...
# 3825  0      0.266434
# 1      0.022767
# 2      0.02276...
# 3826  0      0.022767
# 1      0.022767
# 2      0.26324...
# 3827  0      0.022767
# 1      0.263241
# 2      0.26498...
# 3828  0      0.263241
# 1      0.264989
# 2      0.26821...
#
#                                            AAPL_CALL_VM  \
# 0     0      0.007441
# 1      0.009329
# 2      0.00598...
# 1     0      0.009329
# 1      0.005982
# 2      0.00563...
# 2     0      0.005982
# 1      0.005635
# 2      0.00383...
# 3     0      0.005635
# 1      0.003838
# 2      0.00454...
# 4     0      0.003838
# 1      0.004543
# 2      0.00414...
# ...                                                 ...
# 3824  0      0.026366
# 1      0.027544
# 2      0.02841...
# 3825  0      0.027544
# 1      0.028418
# 2      0.00000...
# 3826  0      0.028418
# 1      0.000000
# 2      0.04094...
# 3827  0      0.000000
# 1      0.040942
# 2      0.01568...
# 3828  0      0.040942
# 1      0.015683
# 2      0.02957...
#
#                                             AAPL_PUT_OM  \
# 0     0      0.136778
# 1      0.144681
# 2      0.09878...
# 1     0      0.144681
# 1      0.098784
# 2      0.13373...
# 2     0      0.098784
# 1      0.133739
# 2      0.08814...
# 3     0      0.133739
# 1      0.088146
# 2      0.10030...
# 4     0      0.088146
# 1      0.100304
# 2      0.05531...
# ...                                                 ...
# 3824  0      0.106383
# 1      0.103343
# 2      0.06990...
# 3825  0      0.103343
# 1      0.069909
# 2      0.06990...
# 3826  0      0.069909
# 1      0.069909
# 2      0.08510...
# 3827  0      0.069909
# 1      0.085106
# 2      0.07051...
# 3828  0      0.085106
# 1      0.070517
# 2      0.09179...
#
#                                             AAPL_PUT_O1  \
# 0     0      0.122097
# 1      0.109138
# 2      0.11770...
# 1     0      0.109138
# 1      0.117702
# 2      0.11330...
# 2     0      0.117702
# 1      0.113308
# 2      0.10061...
# 3     0      0.113308
# 1      0.100619
# 2      0.09313...
# 4     0      0.100619
# 1      0.093131
# 2      0.08367...
# ...                                                 ...
# 3824  0      0.027711
# 1      0.027935
# 2      0.03327...
# 3825  0      0.027935
# 1      0.033271
# 2      0.03327...
# 3826  0      0.033271
# 1      0.033271
# 2      0.03546...
# 3827  0      0.033271
# 1      0.035468
# 2      0.03524...
# 3828  0      0.035468
# 1      0.035243
# 2      0.02901...
#
#                                             AAPL_PUT_OY  \
# 0     0      0.052680
# 1      0.048656
# 2      0.05313...
# 1     0      0.048656
# 1      0.053133
# 2      0.05137...
# 2     0      0.053133
# 1      0.051371
# 2      0.04848...
# 3     0      0.051371
# 1      0.048489
# 2      0.04801...
# 4     0      0.048489
# 1      0.048013
# 2      0.04415...
# ...                                                 ...
# 3824  0      0.004001
# 1      0.004311
# 2      0.00493...
# 3825  0      0.004311
# 1      0.004930
# 2      0.00493...
# 3826  0      0.004930
# 1      0.004930
# 2      0.00576...
# 3827  0      0.004930
# 1      0.005763
# 2      0.00526...
# 3828  0      0.005763
# 1      0.005263
# 2      0.00428...
#
#                                             AAPL_PUT_OI  ...  \
# 0     0      0.130542
# 1      0.094416
# 2      0.09845...  ...
# 1     0      0.094416
# 1      0.098452
# 2      0.10627...  ...
# 2     0      0.098452
# 1      0.106272
# 2      0.10755...  ...
# 3     0      0.106272
# 1      0.107550
# 2      0.10888...  ...
# 4     0      0.107550
# 1      0.108889
# 2      0.11069...  ...
# ...                                                 ...  ...
# 3824  0      0.280257
# 1      0.280613
# 2      0.05861...  ...
# 3825  0      0.280613
# 1      0.058610
# 2      0.05861...  ...
# 3826  0      0.058610
# 1      0.058610
# 2      0.28828...  ...
# 3827  0      0.058610
# 1      0.288284
# 2      0.29109...  ...
# 3828  0      0.288284
# 1      0.291094
# 2      0.29299...  ...
#
#                                             SPX_CALL_OY  \
# 0     0      0.448234
# 1      0.429218
# 2      0.48022...
# 1     0      0.429218
# 1      0.480229
# 2      0.46453...
# 2     0      0.480229
# 1      0.464534
# 2      0.46785...
# 3     0      0.464534
# 1      0.467854
# 2      0.43767...
# 4     0      0.467854
# 1      0.437670
# 2      0.42378...
# ...                                                 ...
# 3824  0      0.064896
# 1      0.062179
# 2      0.05735...
# 3825  0      0.062179
# 1      0.057350
# 2      0.05735...
# 3826  0      0.057350
# 1      0.057350
# 2      0.07153...
# 3827  0      0.057350
# 1      0.071536
# 2      0.06731...
# 3828  0      0.071536
# 1      0.067311
# 2      0.05765...
#
#                                             SPX_CALL_OI  \
# 0     0      0.495566
# 1      0.505046
# 2      0.49420...
# 1     0      0.505046
# 1      0.494204
# 2      0.48760...
# 2     0      0.494204
# 1      0.487602
# 2      0.52304...
# 3     0      0.487602
# 1      0.523048
# 2      0.53778...
# 4     0      0.523048
# 1      0.537780
# 2      0.55145...
# ...                                                 ...
# 3824  0      0.654511
# 1      0.662201
# 2      0.22097...
# 3825  0      0.662201
# 1      0.220977
# 2      0.22097...
# 3826  0      0.220977
# 1      0.220977
# 2      0.67553...
# 3827  0      0.220977
# 1      0.675534
# 2      0.67970...
# 3828  0      0.675534
# 1      0.679701
# 2      0.69024...
#
#                                             SPX_CALL_VM  \
# 0     0      0.381835
# 1      0.223861
# 2      0.20692...
# 1     0      0.223861
# 1      0.206929
# 2      0.12472...
# 2     0      0.206929
# 1      0.124725
# 2      0.23893...
# 3     0      0.124725
# 1      0.238938
# 2      0.25547...
# 4     0      0.238938
# 1      0.255477
# 2      0.20065...
# ...                                                 ...
# 3824  0      0.276654
# 1      0.197751
# 2      0.19560...
# 3825  0      0.197751
# 1      0.195602
# 2      0.00000...
# 3826  0      0.195602
# 1      0.000000
# 2      0.19134...
# 3827  0      0.000000
# 1      0.191341
# 2      0.18697...
# 3828  0      0.191341
# 1      0.186973
# 2      0.33965...
#
#                                              SPX_PUT_OM  \
# 0     0      0.095962
# 1      0.085193
# 2      0.09166...
# 1     0      0.085193
# 1      0.091668
# 2      0.08519...
# 2     0      0.091668
# 1      0.085193
# 2      0.07701...
# 3     0      0.085193
# 1      0.077015
# 2      0.07190...
# 4     0      0.077015
# 1      0.071903
# 2      0.07190...
# ...                                                 ...
# 3824  0      0.190833
# 1      0.188789
# 2      0.19816...
# 3825  0      0.188789
# 1      0.198160
# 2      0.19816...
# 3826  0      0.198160
# 1      0.198160
# 2      0.19492...
# 3827  0      0.198160
# 1      0.194922
# 2      0.18589...
# 3828  0      0.194922
# 1      0.185892
# 2      0.17924...
#
#                                              SPX_PUT_O1  \
# 0     0      0.282048
# 1      0.263833
# 2      0.30178...
# 1     0      0.263833
# 1      0.301780
# 2      0.29598...
# 2     0      0.301780
# 1      0.295985
# 2      0.27363...
# 3     0      0.295985
# 1      0.273630
# 2      0.24396...
# 4     0      0.273630
# 1      0.243963
# 2      0.24492...
# ...                                                 ...
# 3824  0      0.077273
# 1      0.076169
# 2      0.08679...
# 3825  0      0.076169
# 1      0.086795
# 2      0.08679...
# 3826  0      0.086795
# 1      0.086795
# 2      0.09507...
# 3827  0      0.086795
# 1      0.095074
# 2      0.09190...
# 3828  0      0.095074
# 1      0.091900
# 2      0.08693...
#
#                                              SPX_PUT_OY  \
# 0     0      0.312108
# 1      0.314138
# 2      0.33370...
# 1     0      0.314138
# 1      0.333702
# 2      0.33425...
# 2     0      0.333702
# 1      0.334256
# 2      0.31155...
# 3     0      0.334256
# 1      0.311554
# 2      0.30435...
# 4     0      0.311554
# 1      0.304356
# 2      0.30084...
# ...                                                 ...
# 3824  0      0.074013
# 1      0.072905
# 2      0.07622...
# 3825  0      0.072905
# 1      0.076227
# 2      0.07622...
# 3826  0      0.076227
# 1      0.076227
# 2      0.07881...
# 3827  0      0.076227
# 1      0.078811
# 2      0.07567...
# 3828  0      0.078811
# 1      0.075674
# 2      0.07272...
#
#                                              SPX_PUT_OI  \
# 0     0      0.471325
# 1      0.485479
# 2      0.47794...
# 1     0      0.485479
# 1      0.477943
# 2      0.44443...
# 2     0      0.477943
# 1      0.444433
# 2      0.50988...
# 3     0      0.444433
# 1      0.509886
# 2      0.51444...
# 4     0      0.509886
# 1      0.514445
# 2      0.52058...
# ...                                                 ...
# 3824  0      0.754191
# 1      0.764281
# 2      0.19753...
# 3825  0      0.764281
# 1      0.197530
# 2      0.19753...
# 3826  0      0.197530
# 1      0.197530
# 2      0.77644...
# 3827  0      0.197530
# 1      0.776441
# 2      0.77972...
# 3828  0      0.776441
# 1      0.779728
# 2      0.78882...
#
#                                              SPX_PUT_VM  \
# 0     0      0.202485
# 1      0.128264
# 2      0.13495...
# 1     0      0.128264
# 1      0.134954
# 2      0.13534...
# 2     0      0.134954
# 1      0.135345
# 2      0.11055...
# 3     0      0.135345
# 1      0.110553
# 2      0.13102...
# 4     0      0.110553
# 1      0.131024
# 2      0.07958...
# ...                                                 ...
# 3824  0      0.266159
# 1      0.132977
# 2      0.11947...
# 3825  0      0.132977
# 1      0.119472
# 2      0.00000...
# 3826  0      0.119472
# 1      0.000000
# 2      0.14508...
# 3827  0      0.000000
# 1      0.145080
# 2      0.13685...
# 3828  0      0.145080
# 1      0.136854
# 2      0.21118...
#
#                                             RETURN_AAPL Target
# 0     0      0.877078
# 1      0.904260
# 2      0.86155...    0.0
# 1     0      0.904260
# 1      0.861557
# 2      0.85198...    1.0
# 2     0      0.861557
# 1      0.851982
# 2      0.89399...    1.0
# 3     0      0.851982
# 1      0.893998
# 2      0.90449...    1.0
# 4     0      0.893998
# 1      0.904494
# 2      0.89600...    0.0
# ...                                                 ...    ...
# 3824  0      0.872143
# 1      0.875462
# 2      0.86842...    1.0
# 3825  0      0.875462
# 1      0.868428
# 2      0.87707...    0.0
# 3826  0      0.868428
# 1      0.877078
# 2      0.87285...    1.0
# 3827  0      0.877078
# 1      0.872857
# 2      0.88137...    1.0
# 3828  0      0.872857
# 1      0.881372
# 2      0.88861...    0.0
#
# [3829 rows x 57 columns]

# %%
stocks = 'AAPL_MSFT_AMZN_NVDA_SPX'

# %%
output_filename = f'{stocks}_{window_size}.csv'
output_data_folder = os.path.join(project_dir, 'processed_data/options_and_combinations')
reshaped_df.to_csv(os.path.join(output_data_folder, output_filename))

# %%
pkl_filename = f'{stocks}_{window_size}.pkl'
reshaped_df.to_pickle(os.path.join(output_data_folder, pkl_filename))
